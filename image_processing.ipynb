# %% [markdown]
# <a href="https://colab.research.google.com/github/selvavivaan/selvavivaan/blob/main/image_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

# %%
image =cv2.imread('flower.jpg');

# %%
cv2_imshow(image);
# Out:
# <PIL.Image.Image image mode=RGB size=183x275 at 0x7FEF1D2F2210>

# %%
gray =cv2.cvtColor(image, cv2.COLOR_BGR2GRAY);

# %%
cv2_imshow(gray);
# Out:
# <PIL.Image.Image image mode=L size=183x275 at 0x7FEF19233BD0>

# %%
thresh,bandw = cv2.threshold(gray,100,255,cv2.THRESH_BINARY)

# %%
##cv2_imshow(bandw)
# Out:
# <PIL.Image.Image image mode=L size=183x275 at 0x7FEF191CD910>
